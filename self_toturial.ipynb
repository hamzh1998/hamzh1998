# %% [markdown]
# <a href="https://colab.research.google.com/github/hamzh1998/hamzh1998/blob/main/self_toturial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import matplotlib.pyplot as plt

def f(x):
  return x**2

x = np.linspace(-10,10,500)
y=f(x)

# using the rate
delta_x = 0.0001
y1 = (f(x+delta_x)-f(x))/delta_x
# using the rule to find out the derivative
y2 = 2*x

fig = plt.figure(figsize=(12,5))
ax = fig.add_subplot(121)
ax.plot(x, y)
ax.set_title("y=f(x)")

# Plot f'(x) on right half of the figure
ax = fig.add_subplot(122)
ax.plot(x, y1, c="r", alpha=0.5, label="rate")
ax.plot(x, y2, c="b", alpha=0.5, label="rule")
ax.set_title("y=f'(x)")
ax.legend()
 
plt.show()
